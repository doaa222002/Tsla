# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import *

# %% [markdown]
# ## **Read Dataset**

# %%
df = pd.read_csv("/kaggle/input/tsla-text/tsla.us.txt")
df.head()
# Out:
#          Date   Open   High    Low  Close    Volume  OpenInt
# 0  2010-06-28  17.00  17.00  17.00  17.00         0        0
# 1  2010-06-29  19.00  25.00  17.54  23.89  18783276        0
# 2  2010-06-30  25.79  30.42  23.30  23.83  17194394        0
# 3  2010-07-01  25.00  25.92  20.27  21.96   8229863        0
# 4  2010-07-02  23.00  23.10  18.71  19.20   5141807        0

# %%
df.tail()
# Out:
#             Date    Open    High     Low   Close   Volume  OpenInt
# 1853  2017-11-06  307.00  307.50  299.01  302.78  6482486        0
# 1854  2017-11-07  301.02  306.50  300.03  306.05  5286320        0
# 1855  2017-11-08  305.50  306.89  301.30  304.31  4725510        0
# 1856  2017-11-09  302.50  304.46  296.30  302.99  5440335        0
# 1857  2017-11-10  302.50  308.36  301.85  302.99  4621912        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1858 entries, 0 to 1857
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     1858 non-null   object
#  1   Open     1858 non-null   float64
#  2   High     1858 non-null   float64
#  3   Low      1858 non-null   float64
#  4   Close    1858 non-null   float64
#  5   Volume   1858 non-null   int64
#  6   OpenInt  1858 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 101.7+ KB

# %% [markdown]
# ## **Split Dataset into Train & Test**

# %%
# train --> 80 %
# test --> 20 %

train_size = int(len(df) * 0.8)  #1486
train_size
# Out:
# 1486

# %%
train = df[0: train_size] # 0 : 1486 - 1 --> 0:1485
train.head()
# Out:
#          Date   Open   High    Low  Close    Volume  OpenInt
# 0  2010-06-28  17.00  17.00  17.00  17.00         0        0
# 1  2010-06-29  19.00  25.00  17.54  23.89  18783276        0
# 2  2010-06-30  25.79  30.42  23.30  23.83  17194394        0
# 3  2010-07-01  25.00  25.92  20.27  21.96   8229863        0
# 4  2010-07-02  23.00  23.10  18.71  19.20   5141807        0

# %%
train.tail()
# Out:
#             Date    Open    High     Low   Close   Volume  OpenInt
# 1481  2016-05-17  209.05  209.82  204.02  204.66  2303002        0
# 1482  2016-05-18  209.15  215.31  207.75  211.17  4454848        0
# 1483  2016-05-19  213.62  216.79  207.30  215.21  6582419        0
# 1484  2016-05-20  216.99  220.55  216.35  220.28  8635216        0
# 1485  2016-05-23  219.87  222.60  215.86  216.22  4335487        0

# %%
data_length = len(df)
data_length
# Out:
# 1858

# %%
test = df[train_size : data_length]  # 1486 ---> 1858
test.head()
# Out:
#             Date    Open    High     Low   Close   Volume  OpenInt
# 1486  2016-05-24  216.60  218.74  215.18  217.91  2928659        0
# 1487  2016-05-25  217.91  221.36  216.51  219.58  2514028        0
# 1488  2016-05-26  220.50  225.26  219.05  225.12  3560997        0
# 1489  2016-05-27  224.99  225.93  220.75  223.04  3081734        0
# 1490  2016-05-31  223.04  224.75  221.50  223.23  2046828        0

# %%
test.tail()
# Out:
#             Date    Open    High     Low   Close   Volume  OpenInt
# 1853  2017-11-06  307.00  307.50  299.01  302.78  6482486        0
# 1854  2017-11-07  301.02  306.50  300.03  306.05  5286320        0
# 1855  2017-11-08  305.50  306.89  301.30  304.31  4725510        0
# 1856  2017-11-09  302.50  304.46  296.30  302.99  5440335        0
# 1857  2017-11-10  302.50  308.36  301.85  302.99  4621912        0

# %%
scaler = MinMaxScaler()

# %%
train = train.loc[: ,['Open']].values
train
# Out:
# array([[ 17.  ],
#        [ 19.  ],
#        [ 25.79],
#        ...,
#        [213.62],
#        [216.99],
#        [219.87]])

# %%
test_array = test.loc[: ,['Open']].values
test_array
# Out:
# array([[216.6  ],
#        [217.91 ],
#        [220.5  ],
#        [224.99 ],
#        [223.04 ],
#        [221.48 ],
#        [219.59 ],
#        [220.   ],
#        [218.   ],
#        [222.24 ],
#        [233.8  ],
#        [234.98 ],
#        [227.39 ],
#        [219.5  ],
#        [218.88 ],
#        [216.95 ],
#        [217.42 ],
#        [217.81 ],
#        [219.5  ],
#        [220.68 ],
#        [199.47 ],
#        [195.69 ],
#        [190.05 ],
#        [190.86 ],
#        [201.89 ],
#        [205.13 ],
#        [212.97 ],
#        [206.14 ],
#        [209.73 ],
#        [210.   ],
#        [213.1  ],
#        [217.8  ],
#        [219.96 ],
#        [224.1  ],
#        [225.5  ],
#        [223.12 ],
#        [222.52 ],
#        [219.64 ],
#        [225.   ],
#        [226.47 ],
#        [226.   ],
#        [221.99 ],
#        [222.27 ],
#        [227.69 ],
#        [229.34 ],
#        [227.95 ],
#        [230.7  ],
#        [235.5  ],
#        [229.37 ],
#        [227.37 ],
#        [225.69 ],
#        [230.   ],
#        [228.   ],
#        [226.82 ],
#        [228.24 ],
#        [226.17 ],
#        [225.41 ],
#        [226.02 ],
#        [225.49 ],
#        [224.33 ],
#        [223.82 ],
#        [223.54 ],
#        [224.17 ],
#        [224.32 ],
#        [227.05 ],
#        [223.11 ],
#        [222.14 ],
#        [220.15 ],
#        [216.11 ],
#        [210.43 ],
#        [209.01 ],
#        [202.33 ],
#        [199.02 ],
#        [205.5  ],
#        [199.55 ],
#        [199.09 ],
#        [195.   ],
#        [197.06 ],
#        [195.75 ],
#        [196.49 ],
#        [200.42 ],
#        [207.   ],
#        [206.85 ],
#        [206.37 ],
#        [206.4  ],
#        [205.99 ],
#        [206.5  ],
#        [209.65 ],
#        [207.51 ],
#        [205.6  ],
#        [202.21 ],
#        [212.3  ],
#        [213.1  ],
#        [212.24 ],
#        [202.46 ],
#        [201.   ],
#        [201.35 ],
#        [201.85 ],
#        [200.95 ],
#        [200.5  ],
#        [200.66 ],
#        [197.05 ],
#        [195.99 ],
#        [199.74 ],
#        [202.12 ],
#        [198.6  ],
#        [201.   ],
#        [202.9  ],
#        [201.   ],
#        [211.34 ],
#        [204.   ],
#        [202.49 ],
#        [198.04 ],
#        [190.05 ],
#        [189.   ],
#        [189.   ],
#        [193.59 ],
#        [193.79 ],
#        [186.875],
#        [191.05 ],
#        [184.24 ],
#        [188.   ],
#        [182.78 ],
#        [182.65 ],
#        [183.49 ],
#        [190.65 ],
#        [185.04 ],
#        [185.84 ],
#        [190.61 ],
#        [193.64 ],
#        [195.48 ],
#        [195.56 ],
#        [191.   ],
#        [188.25 ],
#        [182.88 ],
#        [182.51 ],
#        [185.52 ],
#        [186.15 ],
#        [192.05 ],
#        [190.87 ],
#        [192.8  ],
#        [193.18 ],
#        [198.74 ],
#        [198.41 ],
#        [198.08 ],
#        [202.49 ],
#        [203.05 ],
#        [208.45 ],
#        [208.22 ],
#        [208.   ],
#        [214.88 ],
#        [221.53 ],
#        [218.56 ],
#        [216.3  ],
#        [214.86 ],
#        [214.75 ],
#        [226.42 ],
#        [226.93 ],
#        [228.97 ],
#        [232.   ],
#        [229.07 ],
#        [229.06 ],
#        [230.   ],
#        [236.7  ],
#        [236.65 ],
#        [247.25 ],
#        [245.46 ],
#        [245.85 ],
#        [250.   ],
#        [257.31 ],
#        [254.29 ],
#        [251.38 ],
#        [252.53 ],
#        [249.24 ],
#        [253.05 ],
#        [248.34 ],
#        [251.91 ],
#        [251.   ],
#        [258.19 ],
#        [257.35 ],
#        [266.25 ],
#        [269.79 ],
#        [270.74 ],
#        [279.03 ],
#        [280.   ],
#        [277.6  ],
#        [265.8  ],
#        [275.45 ],
#        [280.31 ],
#        [264.   ],
#        [252.66 ],
#        [248.17 ],
#        [244.19 ],
#        [254.18 ],
#        [249.71 ],
#        [250.74 ],
#        [247.91 ],
#        [251.92 ],
#        [247.   ],
#        [247.63 ],
#        [246.21 ],
#        [244.39 ],
#        [246.11 ],
#        [257.   ],
#        [262.4  ],
#        [264.   ],
#        [260.6  ],
#        [262.83 ],
#        [251.56 ],
#        [255.39 ],
#        [255.7  ],
#        [260.6  ],
#        [277.02 ],
#        [278.34 ],
#        [278.04 ],
#        [278.73 ],
#        [286.9  ],
#        [296.89 ],
#        [302.04 ],
#        [296.88 ],
#        [297.5  ],
#        [309.15 ],
#        [313.38 ],
#        [306.34 ],
#        [296.7  ],
#        [302.7  ],
#        [299.7  ],
#        [302.46 ],
#        [306.51 ],
#        [302.   ],
#        [309.22 ],
#        [308.   ],
#        [312.37 ],
#        [311.69 ],
#        [309.83 ],
#        [314.88 ],
#        [324.   ],
#        [317.67 ],
#        [307.435],
#        [298.   ],
#        [310.9  ],
#        [309.38 ],
#        [321.56 ],
#        [323.4  ],
#        [325.48 ],
#        [318.38 ],
#        [317.59 ],
#        [314.39 ],
#        [307.   ],
#        [315.5  ],
#        [312.8  ],
#        [310.46 ],
#        [306.51 ],
#        [311.02 ],
#        [317.28 ],
#        [326.   ],
#        [337.69 ],
#        [344.   ],
#        [339.77 ],
#        [338.5  ],
#        [344.7  ],
#        [356.34 ],
#        [363.75 ],
#        [374.42 ],
#        [357.99 ],
#        [367.62 ],
#        [381.085],
#        [372.5  ],
#        [377.975],
#        [375.   ],
#        [376.67 ],
#        [374.35 ],
#        [377.99 ],
#        [382.45 ],
#        [386.69 ],
#        [376.4  ],
#        [366.68 ],
#        [370.61 ],
#        [363.71 ],
#        [370.24 ],
#        [347.2  ],
#        [317.26 ],
#        [313.5  ],
#        [312.9  ],
#        [316.   ],
#        [330.4  ],
#        [330.11 ],
#        [323.19 ],
#        [325.54 ],
#        [317.5  ],
#        [328.23 ],
#        [326.9  ],
#        [329.46 ],
#        [330.24 ],
#        [345.   ],
#        [340.36 ],
#        [346.   ],
#        [336.89 ],
#        [335.5  ],
#        [323.   ],
#        [318.94 ],
#        [345.33 ],
#        [347.   ],
#        [357.35 ],
#        [357.53 ],
#        [361.   ],
#        [361.6  ],
#        [356.97 ],
#        [364.63 ],
#        [365.2  ],
#        [363.   ],
#        [361.21 ],
#        [352.91 ],
#        [345.82 ],
#        [341.13 ],
#        [338.99 ],
#        [352.52 ],
#        [354.24 ],
#        [347.28 ],
#        [339.48 ],
#        [349.67 ],
#        [353.55 ],
#        [356.12 ],
#        [353.8  ],
#        [349.5  ],
#        [345.98 ],
#        [348.99 ],
#        [351.35 ],
#        [364.49 ],
#        [363.82 ],
#        [364.33 ],
#        [374.51 ],
#        [380.25 ],
#        [380.   ],
#        [373.   ],
#        [374.9  ],
#        [366.49 ],
#        [353.15 ],
#        [350.93 ],
#        [349.9  ],
#        [339.88 ],
#        [341.86 ],
#        [342.52 ],
#        [335.9  ],
#        [351.25 ],
#        [356.   ],
#        [353.1  ],
#        [349.65 ],
#        [346.8  ],
#        [353.89 ],
#        [352.95 ],
#        [356.98 ],
#        [353.76 ],
#        [350.91 ],
#        [355.97 ],
#        [355.56 ],
#        [352.69 ],
#        [349.88 ],
#        [338.8  ],
#        [336.7  ],
#        [327.78 ],
#        [319.75 ],
#        [319.18 ],
#        [320.23 ],
#        [332.25 ],
#        [300.13 ],
#        [299.5  ],
#        [307.   ],
#        [301.02 ],
#        [305.5  ],
#        [302.5  ],
#        [302.5  ]])

# %%
train_scaled = scaler.fit_transform(train)
train_scaled
# Out:
# array([[0.00316724],
#        [0.01053291],
#        [0.03553935],
#        ...,
#        [0.72728612],
#        [0.73969727],
#        [0.75030383]])

# %%
#test_scaled = scaler.transform(test_array)
#test_scaled

# %%
length = len(train_scaled)
length
# Out:
# 1486

# %%
time_step = 40
x_train = []
y_train = []

# %%
for i in range(time_step, length):
    x_train.append(train_scaled[i - time_step:i, 0])
    y_train.append(train_scaled[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train.shape
# Out:
# (1446, 40)

# %%
y_train.shape
# Out:
# (1446,)

# %%
x_train.shape[1]
# Out:
# 40

# %%
# (1456, 30, 1)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (1446, 40, 1)

# %% [markdown]
# ## **Build RNN Model**

# %%
rnn_model = Sequential()

#add simple rnn layer with tanh activation function & input shape
rnn_model.add(SimpleRNN(50, activation = 'tanh', return_sequences = True,
                       input_shape = (x_train.shape[1], 1)))

#add dropout layer
rnn_model.add(Dropout(0.2))

#add simple rnn layer with tanh activation function 
rnn_model.add(SimpleRNN(50, activation = 'tanh', return_sequences = True))

#add dropout layer
rnn_model.add(Dropout(0.2))

#add simple rnn layer with tanh activation function 
rnn_model.add(SimpleRNN(50, activation = 'tanh', return_sequences = True))

#add dropout layer
rnn_model.add(Dropout(0.2))

rnn_model.add(SimpleRNN(50))
rnn_model.add(Dropout(0.2))

#add output layer
rnn_model.add(Dense(1))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## **Compile & Fit RNN Model**

# %%
rnn_model.compile(optimizer = 'adam', loss = 'mean_squared_error') #MSE

# %%
rnn_model.fit(x_train, y_train, epochs = 20)
# Out:
# Epoch 1/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3117
# Epoch 2/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1580
# Epoch 3/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1154
# Epoch 4/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0965
# Epoch 5/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0692
# Epoch 6/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0556
# Epoch 7/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0416
# Epoch 8/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0446
# Epoch 9/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0338
# Epoch 10/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0312
# Epoch 11/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0298
# Epoch 12/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0252
# Epoch 13/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0231
# Epoch 14/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0220
# Epoch 15/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0204
# Epoch 16/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0172
# Epoch 17/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0188
# Epoch 18/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0142
# Epoch 19/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0155
# Epoch 20/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0147

# %% [markdown]
# ## **Model Testing**

# %%
total_data = pd.concat((df['Open'], test['Open']), axis = 0)
total_data.head()
# Out:
# 0    17.00
# 1    19.00
# 2    25.79
# 3    25.00
# 4    23.00
# Name: Open, dtype: float64

# %%
len(total_data)
# Out:
# 2230

# %%
inputs = total_data[len(total_data) - len(test) - time_step: ].values.reshape(-1,1)

# %%
inputs = scaler.transform(inputs)

# %%
inputs.shape
# Out:
# (412, 1)

# %%
x_test = []
for i in range(time_step, 402):
    x_test.append(inputs[i - time_step:i -0])

# %%
x_test = np.array(x_test)
x_test.shape
# Out:
# (362, 40, 1)

# %%
rnn_pred = rnn_model.predict(x_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step

# %%
rnn_pred = scaler.inverse_transform(rnn_pred)
rnn_pred
# Out:
# array([[295.93237],
#        [285.95462],
#        [271.77524],
#        [255.90704],
#        [246.50375],
#        [245.04082],
#        [245.65312],
#        [247.38867],
#        [248.03476],
#        [248.30118],
#        [243.03978],
#        [244.15154],
#        [247.48154],
#        [253.14235],
#        [251.73926],
#        [245.35101],
#        [243.03676],
#        [241.40192],
#        [241.68448],
#        [242.97159],
#        [248.81618],
#        [243.93219],
#        [237.32599],
#        [227.49138],
#        [221.53235],
#        [221.58536],
#        [221.54842],
#        [226.55197],
#        [230.37494],
#        [232.26938],
#        [232.87097],
#        [231.73526],
#        [237.3335 ],
#        [242.8198 ],
#        [242.27884],
#        [238.87704],
#        [239.27473],
#        [240.85815],
#        [240.7191 ],
#        [246.08618],
#        [252.09348],
#        [252.14296],
#        [251.07928],
#        [250.4438 ],
#        [251.01802],
#        [254.06299],
#        [254.42255],
#        [254.62543],
#        [254.65173],
#        [254.85832],
#        [255.01984],
#        [253.93124],
#        [255.06725],
#        [255.89464],
#        [255.01683],
#        [253.29684],
#        [251.51038],
#        [252.33476],
#        [251.83476],
#        [253.7133 ],
#        [254.82426],
#        [254.63045],
#        [252.73595],
#        [250.69736],
#        [251.4481 ],
#        [252.04892],
#        [252.97559],
#        [252.52115],
#        [252.13445],
#        [250.39963],
#        [247.29883],
#        [243.58287],
#        [240.53433],
#        [237.96849],
#        [236.2709 ],
#        [234.0389 ],
#        [232.68419],
#        [231.64624],
#        [230.22513],
#        [229.04803],
#        [228.6154 ],
#        [228.95729],
#        [230.40358],
#        [232.30109],
#        [234.02046],
#        [235.59431],
#        [235.67079],
#        [236.31459],
#        [236.95671],
#        [237.39934],
#        [237.67249],
#        [237.23853],
#        [237.33472],
#        [237.91763],
#        [239.71223],
#        [239.57605],
#        [238.28363],
#        [235.9265 ],
#        [234.28531],
#        [233.09703],
#        [231.74406],
#        [232.01591],
#        [232.01485],
#        [230.88611],
#        [229.71422],
#        [229.15973],
#        [229.58134],
#        [230.5027 ],
#        [232.36794],
#        [233.11205],
#        [234.93178],
#        [235.23672],
#        [235.42912],
#        [235.19482],
#        [233.67168],
#        [230.58891],
#        [226.9496 ],
#        [225.31145],
#        [225.64232],
#        [225.65932],
#        [224.4371 ],
#        [223.56976],
#        [222.60876],
#        [220.01445],
#        [217.5087 ],
#        [216.81082],
#        [218.33475],
#        [219.26305],
#        [219.08835],
#        [219.3854 ],
#        [221.16504],
#        [222.61093],
#        [224.74496],
#        [226.2834 ],
#        [226.51164],
#        [224.7585 ],
#        [220.45532],
#        [218.8148 ],
#        [218.7323 ],
#        [219.42369],
#        [221.97401],
#        [223.00674],
#        [225.9356 ],
#        [227.05693],
#        [228.57713],
#        [229.66917],
#        [230.90723],
#        [232.16791],
#        [232.8499 ],
#        [234.36945],
#        [236.79369],
#        [240.07016],
#        [243.97206],
#        [246.19048],
#        [247.69609],
#        [247.61601],
#        [246.6616 ],
#        [247.73782],
#        [248.99347],
#        [252.66336],
#        [255.3242 ],
#        [256.5631 ],
#        [256.80496],
#        [257.21497],
#        [258.46616],
#        [259.88916],
#        [262.53006],
#        [263.6633 ],
#        [265.21304],
#        [267.02362],
#        [268.64453],
#        [271.8175 ],
#        [273.11197],
#        [274.25677],
#        [271.75613],
#        [270.61652],
#        [269.64346],
#        [270.58493],
#        [271.51782],
#        [271.87646],
#        [273.60367],
#        [274.05658],
#        [277.24393],
#        [278.63388],
#        [282.3505 ],
#        [284.6267 ],
#        [286.72174],
#        [284.32468],
#        [281.7186 ],
#        [281.90652],
#        [282.45016],
#        [281.8481 ],
#        [277.41843],
#        [272.2654 ],
#        [268.52203],
#        [268.6362 ],
#        [268.04126],
#        [269.36276],
#        [270.1887 ],
#        [269.8923 ],
#        [268.17032],
#        [266.7407 ],
#        [266.36185],
#        [267.11264],
#        [267.8277 ],
#        [270.2805 ],
#        [272.3249 ],
#        [274.72842],
#        [276.15024],
#        [276.31052],
#        [274.91885],
#        [272.44968],
#        [271.56482],
#        [273.73013],
#        [280.13916],
#        [283.38647],
#        [285.6485 ],
#        [286.7403 ],
#        [289.2506 ],
#        [292.08618],
#        [293.16632],
#        [294.25375],
#        [296.91748],
#        [298.50223],
#        [298.984  ],
#        [296.44247],
#        [297.07376],
#        [298.26877],
#        [298.60516],
#        [297.2389 ],
#        [295.83865],
#        [298.03625],
#        [298.89893],
#        [300.94962],
#        [299.62393],
#        [299.57947],
#        [300.21066],
#        [302.13943],
#        [304.10327],
#        [303.7391 ],
#        [301.27487],
#        [296.80487],
#        [296.66782],
#        [298.3721 ],
#        [301.9258 ],
#        [304.61472],
#        [305.80173],
#        [305.53494],
#        [303.08997],
#        [300.15103],
#        [299.6559 ],
#        [300.48898],
#        [301.0584 ],
#        [298.1109 ],
#        [297.53613],
#        [299.29758],
#        [303.284  ],
#        [308.1819 ],
#        [308.69724],
#        [309.89316],
#        [308.72995],
#        [311.87274],
#        [313.19626],
#        [316.85376],
#        [319.87827],
#        [319.54968],
#        [319.1963 ],
#        [319.19363],
#        [319.95084],
#        [321.7666 ],
#        [324.9271 ],
#        [324.09848],
#        [320.47943],
#        [318.13513],
#        [317.87708],
#        [322.47787],
#        [326.37408],
#        [324.87253],
#        [321.49133],
#        [315.15903],
#        [316.4092 ],
#        [314.19272],
#        [311.51413],
#        [307.8134 ],
#        [303.0377 ],
#        [299.04297],
#        [298.3699 ],
#        [302.3546 ],
#        [303.37912],
#        [307.9058 ],
#        [304.93042],
#        [303.1271 ],
#        [303.9816 ],
#        [303.75616],
#        [305.67963],
#        [305.93723],
#        [309.42633],
#        [310.2888 ],
#        [311.468  ],
#        [310.8592 ],
#        [311.5531 ],
#        [308.17862],
#        [306.07474],
#        [304.95572],
#        [308.35416],
#        [314.72983],
#        [318.90045],
#        [320.16653],
#        [319.06052],
#        [318.72244],
#        [315.93295],
#        [317.68222],
#        [318.36307],
#        [320.05267],
#        [315.33865],
#        [312.52216],
#        [310.2021 ],
#        [311.60425],
#        [315.70792],
#        [316.1882 ],
#        [315.3931 ],
#        [311.0136 ],
#        [311.4639 ],
#        [312.95465],
#        [315.748  ],
#        [316.5105 ],
#        [313.3389 ],
#        [311.8412 ],
#        [312.50372],
#        [314.57068],
#        [318.42108],
#        [318.8286 ],
#        [319.10934],
#        [317.01373],
#        [318.7504 ],
#        [321.96024],
#        [324.33673],
#        [324.28342],
#        [319.03116],
#        [313.91275],
#        [310.52994],
#        [310.0377 ],
#        [310.6615 ],
#        [312.89117],
#        [311.22568],
#        [311.37436],
#        [311.50055],
#        [312.4676 ],
#        [313.65494],
#        [314.46857],
#        [315.7039 ],
#        [315.40454],
#        [315.12225],
#        [313.7204 ],
#        [314.12463],
#        [315.57764],
#        [317.224  ],
#        [315.5974 ],
#        [313.89362],
#        [312.9735 ],
#        [310.68918],
#        [309.28903]], dtype=float32)

# %%
plt.plot(test_array, color = 'red', label = 'Real Price')
plt.plot(rnn_pred, color = 'blue', label = 'Predicted Price')
plt.title("Tsla Stock Prices Prediction")
plt.xlabel("Time")
plt.ylabel("Price")
plt.legend()
plt.show()

# %% [markdown]
# ## **LSTM Model**

# %%
lstm_model = Sequential()

#add simple rnn layer with tanh activation function, with input shape
lstm_model.add(LSTM(50, activation = 'tanh', return_sequences = True, 
                       input_shape = (x_train.shape[1], 1)))
#add dropout layer
lstm_model.add(Dropout(0.2))

#add simple rnn layer with tanh activation function
lstm_model.add(LSTM(50,  return_sequences = True))
#add dropout layer
lstm_model.add(Dropout(0.2))

#add simple rnn layer with tanh activation function
lstm_model.add(LSTM(50, return_sequences = True))
#add dropout layer
lstm_model.add(Dropout(0.2))

#add simple rnn layer 
lstm_model.add(LSTM(50))
#add dropout layer
lstm_model.add(Dropout(0.2))

#add dense layer--> output
lstm_model.add(Dense(1))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
lstm_model.compile(optimizer = 'adam', loss = 'MSE')
lstm_model.fit(x_train, y_train, epochs = 20)
# Out:
# Epoch 1/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0666
# Epoch 2/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0077
# Epoch 3/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0054
# Epoch 4/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0052
# Epoch 5/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0059
# Epoch 6/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0046
# Epoch 7/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0048
# Epoch 8/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0047
# Epoch 9/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0055
# Epoch 10/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041
# Epoch 11/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038
# Epoch 12/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0037
# Epoch 13/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0045
# Epoch 14/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0036
# Epoch 15/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031
# Epoch 16/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033
# Epoch 17/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035
# Epoch 18/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031
# Epoch 19/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041
# Epoch 20/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037

# %%
lstm_pred = lstm_model.predict(x_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step

# %%
lstm_pred
# Out:
# array([[0.9536186 ],
#        [0.9435039 ],
#        [0.9292605 ],
#        [0.9097912 ],
#        [0.8856086 ],
#        [0.85806715],
#        [0.8289373 ],
#        [0.800048  ],
#        [0.7730891 ],
#        [0.7493557 ],
#        [0.7299299 ],
#        [0.71589816],
#        [0.70787466],
#        [0.7055667 ],
#        [0.7077823 ],
#        [0.7130289 ],
#        [0.7197903 ],
#        [0.72682345],
#        [0.7332534 ],
#        [0.73862153],
#        [0.742791  ],
#        [0.7449609 ],
#        [0.7444044 ],
#        [0.74061674],
#        [0.7336346 ],
#        [0.7243621 ],
#        [0.71406686],
#        [0.7042621 ],
#        [0.69590336],
#        [0.68967146],
#        [0.68587613],
#        [0.6846131 ],
#        [0.6858994 ],
#        [0.6895895 ],
#        [0.6955124 ],
#        [0.7032663 ],
#        [0.71222067],
#        [0.7216394 ],
#        [0.7306674 ],
#        [0.73883003],
#        [0.74589145],
#        [0.75179124],
#        [0.75622725],
#        [0.7591404 ],
#        [0.7608063 ],
#        [0.761642  ],
#        [0.761966  ],
#        [0.76212496],
#        [0.7625622 ],
#        [0.7633308 ],
#        [0.7642474 ],
#        [0.7650227 ],
#        [0.7656053 ],
#        [0.7659286 ],
#        [0.76591265],
#        [0.7655826 ],
#        [0.76493424],
#        [0.7639586 ],
#        [0.76271343],
#        [0.7612695 ],
#        [0.75967026],
#        [0.75796   ],
#        [0.756163  ],
#        [0.75437015],
#        [0.7526829 ],
#        [0.75130373],
#        [0.7502458 ],
#        [0.74941486],
#        [0.74863815],
#        [0.74760085],
#        [0.7458705 ],
#        [0.7431303 ],
#        [0.73904   ],
#        [0.73339266],
#        [0.72651917],
#        [0.7187415 ],
#        [0.7104487 ],
#        [0.70191264],
#        [0.69350463],
#        [0.68554616],
#        [0.6783595 ],
#        [0.6723497 ],
#        [0.66807   ],
#        [0.6658731 ],
#        [0.6658205 ],
#        [0.66772383],
#        [0.67118526],
#        [0.67571783],
#        [0.6809445 ],
#        [0.68643486],
#        [0.69169486],
#        [0.6961892 ],
#        [0.69992983],
#        [0.7031184 ],
#        [0.70591587],
#        [0.7080369 ],
#        [0.70913845],
#        [0.7090211 ],
#        [0.7076932 ],
#        [0.70529133],
#        [0.7020401 ],
#        [0.6982319 ],
#        [0.6940392 ],
#        [0.6895929 ],
#        [0.6851889 ],
#        [0.6812166 ],
#        [0.6778694 ],
#        [0.67531   ],
#        [0.6736949 ],
#        [0.67300653],
#        [0.6735309 ],
#        [0.6751552 ],
#        [0.677554  ],
#        [0.68015516],
#        [0.6821258 ],
#        [0.6828176 ],
#        [0.6818798 ],
#        [0.67947924],
#        [0.67601025],
#        [0.6716961 ],
#        [0.66692114],
#        [0.6618256 ],
#        [0.6566775 ],
#        [0.65156674],
#        [0.6465542 ],
#        [0.6417567 ],
#        [0.6375862 ],
#        [0.63420695],
#        [0.63168967],
#        [0.6302127 ],
#        [0.62997866],
#        [0.63113105],
#        [0.6336289 ],
#        [0.6371204 ],
#        [0.6410228 ],
#        [0.6445802 ],
#        [0.6471544 ],
#        [0.6485014 ],
#        [0.6486562 ],
#        [0.6480428 ],
#        [0.6470883 ],
#        [0.64621776],
#        [0.64575434],
#        [0.64607775],
#        [0.64739406],
#        [0.6497085 ],
#        [0.6530351 ],
#        [0.6572679 ],
#        [0.66240656],
#        [0.6683337 ],
#        [0.67477506],
#        [0.6816895 ],
#        [0.68920225],
#        [0.69721067],
#        [0.70534986],
#        [0.71310174],
#        [0.71999294],
#        [0.72614026],
#        [0.73177963],
#        [0.737165  ],
#        [0.742532  ],
#        [0.74787366],
#        [0.7530199 ],
#        [0.7578096 ],
#        [0.7623405 ],
#        [0.7667049 ],
#        [0.77135617],
#        [0.7765458 ],
#        [0.782286  ],
#        [0.78857404],
#        [0.795567  ],
#        [0.80311817],
#        [0.8107783 ],
#        [0.8180838 ],
#        [0.8244789 ],
#        [0.8297057 ],
#        [0.8334681 ],
#        [0.83578306],
#        [0.8367771 ],
#        [0.83695817],
#        [0.8367938 ],
#        [0.83700114],
#        [0.8382434 ],
#        [0.8409041 ],
#        [0.84537554],
#        [0.8517325 ],
#        [0.85959214],
#        [0.86782026],
#        [0.8757205 ],
#        [0.88300335],
#        [0.88881123],
#        [0.89202267],
#        [0.89179903],
#        [0.88774884],
#        [0.88049746],
#        [0.8708818 ],
#        [0.85992765],
#        [0.8485405 ],
#        [0.83767736],
#        [0.8279151 ],
#        [0.8196449 ],
#        [0.81302035],
#        [0.80797786],
#        [0.80443656],
#        [0.80271703],
#        [0.8032472 ],
#        [0.80625457],
#        [0.8114738 ],
#        [0.8184375 ],
#        [0.8260435 ],
#        [0.8333886 ],
#        [0.8398075 ],
#        [0.84509665],
#        [0.84994376],
#        [0.8550562 ],
#        [0.86084294],
#        [0.86739725],
#        [0.87487936],
#        [0.88363045],
#        [0.8938941 ],
#        [0.9052877 ],
#        [0.9171518 ],
#        [0.9292294 ],
#        [0.94137496],
#        [0.95300066],
#        [0.9630454 ],
#        [0.9709254 ],
#        [0.9762413 ],
#        [0.9790474 ],
#        [0.97981197],
#        [0.9788849 ],
#        [0.9769657 ],
#        [0.9746416 ],
#        [0.9725466 ],
#        [0.9710961 ],
#        [0.970386  ],
#        [0.97057945],
#        [0.9720925 ],
#        [0.97483796],
#        [0.9780484 ],
#        [0.980561  ],
#        [0.982085  ],
#        [0.9825733 ],
#        [0.98269874],
#        [0.98318386],
#        [0.98459184],
#        [0.9868497 ],
#        [0.9896232 ],
#        [0.9923845 ],
#        [0.9943399 ],
#        [0.99534714],
#        [0.9953567 ],
#        [0.99437606],
#        [0.9923731 ],
#        [0.9896145 ],
#        [0.9867289 ],
#        [0.98465955],
#        [0.98460275],
#        [0.9875242 ],
#        [0.99351966],
#        [1.0020127 ],
#        [1.0123631 ],
#        [1.0242761 ],
#        [1.0375627 ],
#        [1.0522258 ],
#        [1.0671402 ],
#        [1.0815356 ],
#        [1.0952796 ],
#        [1.1078097 ],
#        [1.1188312 ],
#        [1.1279483 ],
#        [1.1349928 ],
#        [1.1398033 ],
#        [1.1425705 ],
#        [1.1437771 ],
#        [1.1440883 ],
#        [1.1435754 ],
#        [1.1418333 ],
#        [1.1387842 ],
#        [1.1342744 ],
#        [1.1287138 ],
#        [1.1216589 ],
#        [1.1116059 ],
#        [1.0977355 ],
#        [1.0801021 ],
#        [1.059692  ],
#        [1.0385396 ],
#        [1.0186864 ],
#        [1.0014956 ],
#        [0.98794675],
#        [0.9782281 ],
#        [0.9725677 ],
#        [0.97082543],
#        [0.9726539 ],
#        [0.9774944 ],
#        [0.9852436 ],
#        [0.9953335 ],
#        [1.0071964 ],
#        [1.0196558 ],
#        [1.0314841 ],
#        [1.0411584 ],
#        [1.0474999 ],
#        [1.0511677 ],
#        [1.0531642 ],
#        [1.054867  ],
#        [1.0572116 ],
#        [1.060862  ],
#        [1.0659786 ],
#        [1.0720576 ],
#        [1.0788069 ],
#        [1.0858274 ],
#        [1.0925951 ],
#        [1.0985383 ],
#        [1.1028727 ],
#        [1.1047988 ],
#        [1.1037664 ],
#        [1.0996284 ],
#        [1.0933324 ],
#        [1.0860909 ],
#        [1.0786514 ],
#        [1.0712835 ],
#        [1.0645576 ],
#        [1.0591369 ],
#        [1.0556322 ],
#        [1.0541981 ],
#        [1.054507  ],
#        [1.0559379 ],
#        [1.0579815 ],
#        [1.0603412 ],
#        [1.0634148 ],
#        [1.067416  ],
#        [1.0723993 ],
#        [1.0785964 ],
#        [1.0862314 ],
#        [1.0951436 ],
#        [1.1045692 ],
#        [1.1136917 ],
#        [1.1214597 ],
#        [1.1264939 ],
#        [1.1279565 ],
#        [1.1256151 ],
#        [1.1194136 ],
#        [1.1099719 ],
#        [1.0982066 ],
#        [1.0849706 ],
#        [1.0718269 ],
#        [1.060382  ],
#        [1.0516584 ],
#        [1.0459939 ],
#        [1.0432    ],
#        [1.0431004 ],
#        [1.0452869 ],
#        [1.0493944 ],
#        [1.0547817 ],
#        [1.060659  ],
#        [1.0665619 ],
#        [1.0721189 ],
#        [1.0769532 ],
#        [1.0806422 ],
#        [1.0824525 ],
#        [1.081916  ],
#        [1.0786256 ]], dtype=float32)

# %%
lstm_pred = scaler.inverse_transform(lstm_pred)

# %%
plt.plot(test_array, color = 'red', label = 'Real Price')
plt.plot(lstm_pred, color = 'blue', label = 'Predicted Price')
plt.title("Tsla Stock Prices Prediction")
plt.xlabel("Time")
plt.ylabel("Price")
plt.legend()
plt.show()
